# %% [markdown]
# ![Astrofisica Computacional](../../../new_logo.png)

# %% [markdown]
# # Sunpy
#
# <p style="font-size:36px">A Python package for Solar Physics</p>
#
# ## Dr. rer. nat. Jose Ivan Campos Rozo<sup>1,2</sup>
#
# 1. Astronomical Institute of the Czech Academy of Sciences\
#    Department of Solar Physics\
#    Ondřejov, Czec Republic
#
# 2. Observatorio Astronómico Nacional\
#    Facultad de Ciencias\
#    Universidad Nacional de Colombia
#
# e-mail: jicamposr@unal.edu.co & rozo@asu.cas.cz)
#
# ---

# %% [markdown]
# # Associated Packages
# ![paquetes](affiliated_packages.png)

# %% [markdown]
# # Main components of Sunpy
# ![components](components.png)

# %% [markdown]
# <h1>Downloading data (Fido is a simple, asynchronous HTTP client)</h1>
# <h4>Sadly Fido is now RETIRED, meaning that it will no longer be updated</h4>
#
# <p style="font-size:28px">Main servers to download solar data:</p>
# <ul>
#  <li style="font-size:26px"> JSOC --  Joint Science Operations Center</li>
#     <ul>
#         <li style="font-size:24px">
#             Main database for SDO-HMI, SDO-AIA, SOHO-MDI and IRIS telescopes and instruments
#         </li>
#     </ul>
#  <li style="font-size:26px"> NOAA -- National Oceanic and Atmospheric Administration </li>
#     <ul>
#        <li style="font-size:24px">Database for GOES-I, GOES-P and GOES-R series</li>
#     </ul>
#  <li style="font-size:26px">VSO -- Virtual Solar Observatory</li>
#     <ul>
#        <li style="font-size:24px">This database contain most of the satellites and instruments active observing the Sun</li>
#     </ul>
#  <li style="font-size:26px">FTP -- File Transfer Protocol</li>
#     <ul>
#        <li style="font-size:24px">Accept quiet OK any ftp server.</li>
#     </ul>
# </ul>
# <p style="font-size:28px">What kind of features are included when we use Fido and JSOC (main features of Sunpy are developed to/for SDO).</p>
# <ul>
# <li style="font-size:26px">time: date-time, time ranges, different time scales.</li>
# <li style="font-size:26px">wavelength: Some instruments have different filters and wavelengths.</li>
# <li style="font-size:26px">instrument: Some telescopes have on board multiple instruments, then sometimes it is better to choose only one instrument.</li>
# <li style="font-size:26px">physobs: Some instrument, even have different physical observations (e.g. Intensity, Magnetogram, Stokes vector,...)</li>
# <li style="font-size:26px">and some others.</li>
# </ul>

# %% [markdown]
# # Some examples

# %% [markdown]
# ## Acquiring data

# %%
from sunpy.net import Fido, attrs as a
import astropy.units as u

# %%
print(Fido)
# Out:
# sunpy.net.Fido
#
# Fido is a unified data search and retrieval tool.
#
# It provides simultaneous access to a variety of online data sources, some
# cover multiple instruments and data products like the Virtual Solar
# Observatory and some are specific to a single source.
#
# For details of using `~sunpy.net.Fido` see :ref:`sunpy-tutorial-acquiring-data-index`.
#
#
#       Client      ...
# ----------------- ...
# CDAWEBClient      ...
# ADAPTClient       ...
# EVEClient         ...
# GBMClient         ...
# XRSClient         ...
# SUVIClient        ...
# GONGClient        ...
# LYRAClient        ...
# NOAAIndicesClient ...
# NOAAPredictClient ...
# SRSClient         ...
# NoRHClient        ...
# RHESSIClient      ...
# HEKClient         ...
# HECClient         ...
# JSOCClient        ...
# VSOClient         ...

# %%
a.Time('2012/3/4', '2012/3/6')
# Out:
# <sunpy.net.attrs.Time(2012-03-04 00:00:00.000, 2012-03-06 00:00:00.000)>

# %%
print(a.Instrument)
# Out:
# sunpy.net.attrs.Instrument
#
# Specifies the Instrument name for the search.
#
# Attribute Name ...
# -------------- ...
# adapt          ...
# aia            ...
# bcs            ...
# be_continuum   ...
# be_halpha      ...
# bigbear        ...
# caii           ...
# cds            ...
# celias         ...
# cerrotololo    ...
# ...            ...
# vault_1999     ...
# vault_2002     ...
# vault_2014     ...
# virgo          ...
# vsm            ...
# wbs            ...
# wispr          ...
# x123           ...
# xrs            ...
# xrt            ...
# Length = 108 rows

# %%
print(a.Physobs)
# Out:
# sunpy.net.attrs.Physobs
#
# Specifies the physical observable the VSO can search for.
#
#     Attribute Name    ...
# --------------------- ...
# composition           ...
# equivalent_width      ...
# flux                  ...
# flux                  ...
# intensity             ...
# intensity             ...
# irradiance            ...
# irradiance            ...
# irradiance            ...
# irradiance            ...
# ...                   ...
# spectrum              ...
# srs                   ...
# stokes_parameters     ...
# summary_lightcurve    ...
# sunspotnumber         ...
# sunspotnumber         ...
# thermal_velocity      ...
# vector_magnetic_field ...
# vector_magnetic_field ...
# wave_power            ...
# Length = 27 rows

# %%
results = Fido.search(a.Time('2012/3/4', '2012/3/4'), a.Instrument.aia,)
print(results)
# Out:
# Results from 1 Provider:
#
# 2 Results from the VSOClient:
# Source: https://sdac.virtualsolar.org/cgi/search
# Data retrieval status: https://docs.virtualsolar.org/wiki/VSOHealthReport
# Total estimated size: 135.578 Mbyte
#
#        Start Time               End Time        Source ... Extent Type   Size
#                                                        ...              Mibyte
# ----------------------- ----------------------- ------ ... ----------- --------
# 2012-03-04 00:00:00.000 2012-03-04 00:00:01.000    SDO ...    FULLDISK 64.64844
# 2012-03-04 00:00:00.000 2012-03-04 00:00:01.000    SDO ...    FULLDISK 64.64844

# %%
print(results.all_colnames)

# %%
print(results.show("Wavelength"))

# %%
results = Fido.search(a.Time('2012/3/4', '2012/3/4'), a.Instrument.aia,a.Wavelength(171*u.angstrom))
print(results)

# %%
results = Fido.search(a.Time('2012/3/4', '2012/3/5'), a.Instrument.aia,a.Wavelength(171*u.angstrom), a.Sample(120*u.minute))
print(results)

# %%
results = Fido.search(a.Time('2012/3/4', '2012/3/4 02:00'),a.Instrument.lyra | a.Instrument.rhessi)
print(results)

# %%
print(results['lyra'])

# %%
print(results['rhessi'])

# %%
print(results['vso'])

# %%
results = Fido.search(a.Time("2020/01/01", "2020/01/01 00:01"), a.Instrument.aia | a.Instrument.hmi)
print(results)

# %%
print(results.all_colnames)

# %%
print(results.show("Start Time", "Instrument", "Physobs", "Wavelength"))

# %%
aia, hmi = results

# 2026-02-07 10:40:57 - sunpy - WARNING: SunpyUserWarning: Importing sunpy.map without its extra dependencies may result in errors.
# The following packages are not installed:
# ['mpl-animators>=1.0.0', 'reproject>=0.9.0']
# To install sunpy with these dependencies use `pip install sunpy[map]` or `pip install sunpy[all]` for all extras.
# If you installed sunpy via conda, please report this to the community channel: https://matrix.to/#/#sunpy:openastronomy.org
# WARNING: SunpyUserWarning: Importing sunpy.visualization without its extra dependencies may result in errors.
# The following packages are not installed:
# ['mpl-animators>=1.0.0']
# To install sunpy with these dependencies use `pip install sunpy[visualization]` or `pip install sunpy[all]` for all extras.
# If you installed sunpy via conda, please report this to the community channel: https://matrix.to/#/#sunpy:openastronomy.org [sunpy.util.sysinfo]
# 2026-02-07 10:40:58 - sunpy - WARNING: SunpyUserWarning: Importing sunpy.visualization without its extra dependencies may result in errors.
# The following packages are not installed:
# ['mpl-animators>=1.0.0']
# To install sunpy with these dependencies use `pip install sunpy[visualization]` or `pip install sunpy[all]` for all extras.
# If you installed sunpy via conda, please report this to the community channel: https://matrix.to/#/#sunpy:openastronomy.org
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 import sunpy.map as smap
#
# File ~/miniconda3/envs/astrocom/lib/python3.10/site-packages/sunpy/map/__init__.py:10
#       7 from sunpy.util.sysinfo import _warn_missing_deps
#       8 _warn_missing_deps('map')
# ---> 10 from sunpy.map.mapbase import *
#      12 from sunpy.map import sources
#      13 from sunpy.map.header_helper import *
#
# File ~/miniconda3/envs/astrocom/lib/python3.10/site-packages/sunpy/map/mapbase.py:37
#      35 # The next two are not used but are called to register functions with external modules
#      36 import sunpy.coordinates
# ---> 37 import sunpy.visualization.colormaps
#      38 from sunpy import config, log
#      39 from sunpy.coordinates import HeliographicCarrington, get_earth, sun
#
# File ~/miniconda3/envs/astrocom/lib/python3.10/site-packages/sunpy/visualization/colormaps/__init__.py:12
#       1 """
#       2 The following colormaps are provided by this module.
#       3
#    (...)
#      10
#      11 """
# ---> 12 from sunpy.visualization.colormaps.cm import *
#      14 for cmname in cmlist.keys():  # NOQA: F405
#      15     __doc__ += f"\n* '{cmname}'\n"
#
# File ~/miniconda3/envs/astrocom/lib/python3.10/site-packages/sunpy/visualization/colormaps/cm.py:17
#      12 from sunpy.visualization.colormaps import color_tables as ct
#      14 __all__ = ['show_colormaps', 'cmlist']
# ---> 17 sdoaia94 = ct.aia_color_table(94*u.angstrom)
#      18 sdoaia131 = ct.aia_color_table(131*u.angstrom)
#      19 sdoaia171 = ct.aia_color_table(171*u.angstrom)
#
# File ~/miniconda3/envs/astrocom/lib/python3.10/site-packages/astropy/units/decorators.py:313, in QuantityInput.__call__.<locals>.wrapper(*func_args, **func_kwargs)
#     311 # Call the original function with any equivalencies in force.
#     312 with add_enabled_equivalencies(self.equivalencies):
# --> 313     return_ = wrapped_function(*func_args, **func_kwargs)
#     315 # Return
#     316 ra = wrapped_signature.return_annotation
#
# File ~/miniconda3/envs/astrocom/lib/python3.10/site-packages/sunpy/visualization/colormaps/color_tables.py:111, in aia_color_table(wavelength)
#      98 @u.quantity_input
#      99 def aia_color_table(wavelength: u.angstrom):
#     100     """
#     101     Returns one of the fundamental color tables for SDO AIA images.
#     102
#    (...)
#     109         Wavelength for the desired AIA color table.
#     110     """
# --> 111     aia_wave_dict = create_aia_wave_dict()
#     112     try:
#     113         r, g, b = aia_wave_dict[wavelength]
#
# File ~/miniconda3/envs/astrocom/lib/python3.10/site-packages/sunpy/visualization/colormaps/color_tables.py:75, in create_aia_wave_dict()
#      74 def create_aia_wave_dict():
# ---> 75     idl_3 = get_idl3()
#      76     r0, g0, b0 = idl_3[:, 0], idl_3[:, 1], idl_3[:, 2]
#      78     c0 = np.arange(256, dtype='f')
#
# File ~/miniconda3/envs/astrocom/lib/python3.10/site-packages/sunpy/visualization/colormaps/color_tables.py:65, in get_idl3()
#      63 def get_idl3():
#      64     # The following values describe color table 3 for IDL (Red Temperature)
# ---> 65     return np.loadtxt(CMAP_DATA_DIR / 'idl_3.csv', delimiter=',')
#
# File ~/miniconda3/envs/astrocom/lib/python3.10/site-packages/numpy/lib/_npyio_impl.py:1395, in loadtxt(fname, dtype, comments, delimiter, converters, skiprows, usecols, unpack, ndmin, encoding, max_rows, quotechar, like)
#    1392 if isinstance(delimiter, bytes):
#    1393     delimiter = delimiter.decode('latin1')
# -> 1395 arr = _read(fname, dtype=dtype, comment=comment, delimiter=delimiter,
#    1396             converters=converters, skiplines=skiprows, usecols=usecols,
#    1397             unpack=unpack, ndmin=ndmin, encoding=encoding,
#    1398             max_rows=max_rows, quote=quotechar)
#    1400 return arr
#
# File ~/miniconda3/envs/astrocom/lib/python3.10/site-packages/numpy/lib/_npyio_impl.py:1022, in _read(fname, delimiter, comment, quote, imaginary_unit, usecols, skiplines, max_rows, converters, ndmin, unpack, dtype, encoding)
#    1020     fname = os.fspath(fname)
#    1021 if isinstance(fname, str):
# -> 1022     fh = np.lib._datasource.open(fname, 'rt', encoding=encoding)
#    1023     if encoding is None:
#    1024         encoding = getattr(fh, 'encoding', 'latin1')
#
# File ~/miniconda3/envs/astrocom/lib/python3.10/site-packages/numpy/lib/_datasource.py:191, in open(path, mode, destpath, encoding, newline)
#     154 def open(path, mode='r', destpath=os.curdir, encoding=None, newline=None):
#     155     """
#     156     Open `path` with `mode` and return the file object.
#     157
#    (...)
#     188
#     189     """
# --> 191     ds = DataSource(destpath)
#     192     return ds.open(path, mode, encoding=encoding, newline=newline)
#
# File ~/miniconda3/envs/astrocom/lib/python3.10/site-packages/numpy/lib/_datasource.py:248, in DataSource.__init__(self, destpath)
#     246 """Create a DataSource with a local path at destpath."""
#     247 if destpath:
# --> 248     self._destpath = os.path.abspath(destpath)
#     249     self._istmpdest = False
#     250 else:
#
# File ~/miniconda3/envs/astrocom/lib/python3.10/posixpath.py:384, in abspath(path)
#     382         cwd = os.getcwdb()
#     383     else:
# --> 384         cwd = os.getcwd()
#     385     path = join(cwd, path)
#     386 return normpath(path)
#
# FileNotFoundError: [Errno 2] No such file or directory

# %%
my_map = smap.Map(files[0])

# %%
my_map

# %% [markdown]
# ## Making some inspection into our map object

# %%
my_map.date

# %%
my_map.exposure_time

# %% [markdown]
# <p style="font-size:28px">But, how to obtain the data array?</p>

# %%
my_map.data

# %%
print(my_map.dimensions)
print(my_map.dtype)

# %% [markdown]
# ## Look over past lectures

# %% [markdown]
# <p style="font-size:26px">Coordinates and Reference Systems</p>

# %%
my_map.coordinate_frame

# %%
print(my_map.center)
print(my_map.bottom_left_coord)
print(my_map.top_right_coord)

# %% [markdown]
# # Plotting our maps

# %%
my_map.peek()

# %% [markdown]
# <p style="font-size:26px">But this function is not flexible.</p>

# %%
import matplotlib.pyplot as plt

fig = plt.figure()
ax = fig.add_subplot(projection=my_map)
my_map.plot(axes=ax)
plt.colorbar()
plt.show()

# %%
fig = plt.figure()
ax = fig.add_subplot(projection=my_map)
my_map.plot(axes=ax, clip_interval=(1, 99.9)*u.percent)
plt.colorbar()
plt.show()

# %%
fig = plt.figure()
ax = fig.add_subplot(projection=my_map)
my_map.plot(axes=ax, cmap='inferno', clip_interval=(1,99.99)*u.percent)
plt.colorbar()
plt.show()

# %%
import matplotlib.colors

fig = plt.figure()
ax = fig.add_subplot(projection=my_map)
my_map.plot(norm=matplotlib.colors.LogNorm())
plt.colorbar()
plt.show()

# %%
fig = plt.figure()
ax = fig.add_subplot(projection=my_map)
my_map.plot(axes=ax, clip_interval=(1,99.99)*u.percent)
my_map.draw_limb(axes=ax, color='C0')
plt.show()

# %%
from astropy.coordinates import SkyCoord
roi_bottom_left = SkyCoord(Tx=-300*u.arcsec, Ty=-100*u.arcsec, frame=my_map.coordinate_frame)
roi_top_right = SkyCoord(Tx=200*u.arcsec, Ty=400*u.arcsec, frame=my_map.coordinate_frame)
fig = plt.figure()
ax = fig.add_subplot(projection=my_map)
my_map.plot(axes=ax, )
my_map.draw_quadrangle(roi_bottom_left, top_right=roi_top_right, axes=ax, edgecolor='C0')
plt.show()

# %%
my_submap = my_map.submap(roi_bottom_left, top_right=roi_top_right)

fig = plt.figure()
ax = fig.add_subplot(projection=my_submap)
my_submap.plot(axes=ax)
plt.show()

# %%
sequence = smap.Map(files,sequence=True)

# %%
# %matplotlib qt
sequence.peek()

# %% [markdown]
# # Time Series
# <p style="font-size:28px">Another kind of data which we observe in astronomy are the time series</p>

# %%
import sunpy.timeseries
import sunpy.data.sample

sunpy.data.sample.GOES_XRS_TIMESERIES
my_timeseries = sunpy.timeseries.TimeSeries(sunpy.data.sample.GOES_XRS_TIMESERIES)

# %%
print(my_timeseries)

# %%
my_timeseries.columns

# %%
my_timeseries.time

# %%
my_timeseries.time_range

# %% [markdown]
# # Finally We can plot

# %%
# %matplotlib inline
fig, ax = plt.subplots()
my_timeseries.plot(axes=ax)
plt.show()

# %% [markdown]
# # Another examples

# %%
import os

import matplotlib.pyplot as plt

import astropy.units as u
from astropy.coordinates import SkyCoord
from astropy.time import Time
from astropy.visualization import ImageNormalize, SqrtStretch

import sunpy.coordinates  # NOQA
import sunpy.map
from sunpy.net import Fido
from sunpy.net import attrs as a

# %%
start_time = Time('2012-09-24T14:56:03', scale='utc', format='isot')
bottom_left = SkyCoord(-500*u.arcsec, -275*u.arcsec, obstime=start_time, observer="earth", frame="helioprojective")
top_right = SkyCoord(150*u.arcsec, 375*u.arcsec, obstime=start_time, observer="earth", frame="helioprojective")

# %%
cutout = a.jsoc.Cutout(bottom_left, top_right=top_right, tracking=True)

# %%
jsoc_email = "jicamposr@unal.edu.co" # resgister e-mail in http://jsoc.stanford.edu/ajax/register_email.html

# %%
query = Fido.search(
    a.Time(start_time - 6*u.h, start_time + 6*u.h),
    a.Wavelength(171*u.angstrom),
    a.Sample(2*u.h),
    a.jsoc.Series.aia_lev1_euv_12s,
    a.jsoc.Notify(jsoc_email),
    a.jsoc.Segment.image,
    cutout,
)
print(query)

# %%
files = Fido.fetch(query)
files.sort()

# %%
# %matplotlib qt
sequence = sunpy.map.Map(files, sequence=True)

fig = plt.figure()
ax = fig.add_subplot(projection=sequence.maps[0])
ani = sequence.plot(axes=ax, norm=ImageNormalize(vmin=0, vmax=5e3, stretch=SqrtStretch()))

plt.show()

# %% [markdown]
# # Working without SunPy

# %%
from astropy.io import fits
import numpy as np
import matplotlib.pyplot as plt

# %%
hdu = fits.open('DataTests/ManchaNew1/RawContinuum/hmi.ic_720s.20230725_004800_TAI.3.continuum.fits')
print(hdu.info())

# %%
im = hdu[1].data
hdr = hdu[1].header

# %%
# %matplotlib inline
fig, ax = plt.subplots(figsize=(6,6),layout='constrained')
ax.imshow(im,origin='lower',cmap='gray')

# %%
fig, ax = plt.subplots(figsize=(6,6),layout='constrained')
ax.imshow(im,origin='lower',cmap='gray')
ax.set_title(f"SDO/HMI Time: {hdr['date-obs'].replace('T',' ')}")
ax.set_xlabel('x-axis [pixels]')
ax.set_ylabel('y-axis [pixels]')

# %%
fig, ax = plt.subplots(figsize=(6,6),layout='constrained')
ax.imshow(im,origin='lower',cmap='gray',extent=(0,im.shape[1]*hdr['cdelt1'],0,im.shape[0]*hdr['cdelt2']))
ax.set_title(f"SDO/HMI Time: {hdr['date-obs'].replace('T',' ')}")
ax.set_xlabel('x-axis [arcseconds]')
ax.set_ylabel('y-axis [arcseconds]')

# %% [markdown]
# # Working with several files

# %%
import glob

folder = 'DataTests/ManchaNew1/RawContinuum/'
files = sorted(glob.glob(folder+'*.fits'))

datacube = np.zeros([len(files),*im.shape])
for i in range(len(files)):
    datacube[i,...] = fits.getdata(files[i],1)

# %% [markdown]
# ![Astrofisica Computacional](../../new_logo.png)

# %% [markdown]
# # Computational Astrophysics – Plain text files
#
# ## Dr. rer. nat. Jose Ivan Campos Rozo<sup>1,2</sup>
#
# 1. Astronomical Institute of the Czech Academy of Sciences\
#    Department of Solar Physics\
#    Ondřejov, Czec Republic
#
# 2. Observatorio Astronómico Nacional\
#    Facultad de Ciencias\
#    Universidad Nacional de Colombia
#
# e-mail: jicamposr@unal.edu.co & rozo@asu.cas.cz)
#
# ---
# Taken from previous lectures of this course.

# %% [markdown]
# ### About this Notebook
#
# This notebook reviews how to read and load data from plain text files.
#
# ---

# %% [markdown]
# ## 1. Reading plain text files
#
# Using [numpy](https://numpy.org), it is possible to read from a plain text file and load it directly into an array.

# %%
import numpy as np

data = np.loadtxt('example01.txt', comments='#')
data
# Out:
# array([[0.52013, 0.58838],
#        [0.97421, 0.86968],
#        [0.32636, 0.46422],
#        [0.15357, 0.30238],
#        [0.04137, 0.42932],
#        [0.81692, 0.71604],
#        [0.55537, 0.65984],
#        [0.54048, 0.2906 ],
#        [0.19599, 0.46572],
#        [0.99097, 0.92701],
#        [0.34448, 0.42427],
#        [0.1761 , 0.97068],
#        [0.13499, 0.78447],
#        [0.62033, 0.9851 ],
#        [0.17474, 0.66958],
#        [0.69947, 0.61388],
#        [0.64209, 0.72489],
#        [0.93146, 0.48503],
#        [0.06737, 0.96253],
#        [0.20402, 0.54688],
#        [0.61098, 0.04747],
#        [0.68035, 0.80084],
#        [0.1563 , 0.0917 ],
#        [0.38251, 0.77376],
#        [0.42709, 0.72582],
#        [0.10443, 0.59883],
#        [0.05895, 0.08682],
#        [0.58972, 0.67773],
#        [0.85276, 0.24415],
#        [0.41451, 0.49272],
#        [0.951  , 0.86498],
#        [0.33021, 0.64959],
#        [0.32451, 0.10333],
#        [0.46917, 0.93602],
# ...

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(7,5))
plt.plot(data[:,0],data[:,1], color='crimson')
plt.show()

# %% [markdown]
# When the data in the file is separated by a symbol other than a space, it must be written with the `delimiter` argument.

# %%
import numpy as np

data = np.loadtxt('example02.txt', comments='#')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[4], line 3
#       1 import numpy as np
# ----> 3 data = np.loadtxt('example02.txt', comments='#')
#
# File /opt/anaconda3/lib/python3.12/site-packages/numpy/lib/npyio.py:1373, in loadtxt(fname, dtype, comments, delimiter, converters, skiprows, usecols, unpack, ndmin, encoding, max_rows, quotechar, like)
#    1370 if isinstance(delimiter, bytes):
#    1371     delimiter = delimiter.decode('latin1')
# -> 1373 arr = _read(fname, dtype=dtype, comment=comment, delimiter=delimiter,
#    1374             converters=converters, skiplines=skiprows, usecols=usecols,
#    1375             unpack=unpack, ndmin=ndmin, encoding=encoding,
#    1376             max_rows=max_rows, quote=quotechar)
#    1378 return arr
#
# ...

# %%
import numpy as np

data = np.loadtxt('example02.txt', comments='#', delimiter=',')
data
# Out:
# array([[0.81034, 0.2235 ],
#        [0.39312, 0.68131],
#        [0.99453, 0.66464],
#        [0.24778, 0.35242],
#        [0.16555, 0.4546 ],
#        [0.70053, 0.3591 ],
#        [0.66807, 0.10538],
#        [0.37159, 0.41907],
#        [0.81777, 0.08121],
#        [0.55486, 0.17452],
#        [0.39705, 0.75475],
#        [0.02905, 0.4874 ],
#        [0.71874, 0.48111],
#        [0.72678, 0.66784],
#        [0.74849, 0.22783],
#        [0.89764, 0.84021],
#        [0.75019, 0.32162],
#        [0.79706, 0.24939],
#        [0.77985, 0.95716],
#        [0.25888, 0.86171],
#        [0.37601, 0.15616],
#        [0.40273, 0.43479],
#        [0.39627, 0.07058],
#        [0.18511, 0.74248],
#        [0.60697, 0.35105],
#        [0.17853, 0.20858],
#        [0.97507, 0.36384],
#        [0.33934, 0.6788 ],
#        [0.64334, 0.61106],
#        [0.92944, 0.11392],
#        [0.61664, 0.60389],
#        [0.97745, 0.39624],
#        [0.61848, 0.60607],
#        [0.34941, 0.21303],
# ...

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(7,5))
plt.plot(data[:,0],data[:,1], color='crimson')
plt.show()

# %% [markdown]
# ---
#
# ## 02. Writing plain text files
#
# Again, the [numpy](https://numpy.org) library has a simple function for writing plain text files.

# %%
def f(x):
    return np.exp(-x**2/5)

wdata = np.zeros([2,100])

wdata[0,:] = np.linspace(-10,10,100)
wdata[1] = f(wdata[0])


np.savetxt('out_file1.txt', wdata, fmt='%5.5f', header='This is the header of the file')

# %%
outdata = np.loadtxt('out_file1.txt', comments='#')


plt.figure(figsize=(7,5))
plt.plot(outdata[0],outdata[1], color='crimson')
plt.show()

# %%
np.savetxt('out_file2.data', wdata, delimiter = ',', 
           fmt='%5.5f', header='This is the header of the file')

outdata2= np.loadtxt('out_file2.data', comments='#', delimiter=',')


plt.figure(figsize=(7,5))
plt.plot(outdata2[0],outdata2[1], color='crimson')
plt.show()
